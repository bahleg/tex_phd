# %%
import numpy as np
import scipy as st
import matplotlib.pylab as plt
# %matplotlib inline

# %%
from mpl_toolkits.mplot3d import Axes3D
import itertools

x = np.linspace(0,1,50)
y = np.linspace(0,1,50)
z = np.linspace(0,1,50)

points = []
for element in itertools.product(x, y, z):
    points.append(element)

def f(vals):
    return [0.1, 0.1, 0.1, 0.1]

fxyz = list(map(f, points))
xi, yi, zi = (zip(*points))

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xi, yi, zi, c=fxyz, alpha=1.0 )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-91b4adfd69e1> in <module>
#      19 ax = fig.add_subplot(111, projection='3d')
#      20 ax.scatter(xi, yi, zi, c=fxyz, alpha=1.0 )
# ---> 21 plt.show()
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# /usr/local/lib/python3.5/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.5/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import itertools

x = np.linspace(0,1,50)
y = np.linspace(0,1,50)
z = np.linspace(0,1,50)

points = []
for element in itertools.product(x, y, z):
    points.append(element)

def f(vals):
    return [0.1, 0.1, 0.1, 0.1]

fxyz = list(map(f, points))
xi, yi, zi = (zip(*points))

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xi, yi, zi, c=fxyz, alpha=1.0 )
plt.show()

# %%
#http://blog.bogatron.net/blog/2014/02/02/visualizing-dirichlet-distributions/
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as tri

corners = np.array([[0, 0], [1, 0], [0.5, 0.75**0.5]])
triangle = tri.Triangulation(corners[:, 0], corners[:, 1])

# %%
refiner = tri.UniformTriRefiner(triangle)
trimesh = refiner.refine_triangulation(subdiv=4)

plt.figure(figsize=(8, 4))
for (i, mesh) in enumerate((triangle, trimesh)):
    plt.subplot(1, 2, i+ 1)
    plt.triplot(mesh)
    plt.axis('off')
    plt.axis('equal')

# %%
refiner = tri.UniformTriRefiner(triangle)
trimesh = refiner.refine_triangulation(subdiv=4)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, i+ 1)
plt.triplot(triangle)
plt.axis('off')
plt.axis('equal')
# Out:
# (-0.05, 1.05, -0.04330127018922193, 0.9093266739736605)

# %%
# Mid-points of triangle sides opposite of each corner
midpoints = [(corners[(i + 1) % 3] + corners[(i + 2) % 3]) / 2.0 \
             for i in range(3)]
def xy2bc(xy, tol=1.e-3):
    '''Converts 2D Cartesian coordinates to barycentric.'''
    s = [(corners[i] - midpoints[i]).dot(xy - midpoints[i]) / 0.75 \
         for i in range(3)]
    return np.clip(s, tol, 1.0 - tol)

# %%
from functools import reduce
class Dirichlet(object):
    def __init__(self, alpha):
        alpha = [alpha, alpha, alpha]
        from math import gamma
        from operator import mul
        self._alpha = np.array(alpha)
        self._coef = gamma(np.sum(self._alpha)) / \
                     reduce(mul, [gamma(a) for a in self._alpha])
    def pdf(self, x):
        '''Returns pdf value for `x`.'''
        from operator import mul
        return (self._coef * reduce(mul, [xx ** (aa - 1)
                                         for (xx, aa)in zip(x, self._alpha)]))

# %%
trimesh.x, trimesh.y
# Out:
# (array([0.     , 1.     , 0.5    , 0.5    , 0.75   , 0.25   , 0.25   ,
#         0.875  , 0.375  , 0.625  , 0.5    , 0.125  , 0.75   , 0.625  ,
#         0.375  , 0.125  , 0.1875 , 0.3125 , 0.9375 , 0.625  , 0.75   ,
#         0.4375 , 0.6875 , 0.4375 , 0.5625 , 0.625  , 0.3125 , 0.5625 ,
#         0.25   , 0.6875 , 0.5625 , 0.4375 , 0.0625 , 0.375  , 0.1875 ,
#         0.875  , 0.8125 , 0.8125 , 0.5625 , 0.3125 , 0.5    , 0.4375 ,
#         0.6875 , 0.375  , 0.5    , 0.0625 , 0.09375, 0.15625, 0.3125 ,
#         0.375  , 0.21875, 0.21875, 0.28125, 0.3125 , 0.15625, 0.28125,
#         0.96875, 0.8125 , 0.875  , 0.84375, 0.71875, 0.5625 , 0.65625,
#         0.8125 , 0.65625, 0.78125, 0.71875, 0.46875, 0.59375, 0.46875,
#         0.34375, 0.40625, 0.71875, 0.625  , 0.40625, 0.53125, 0.5625 ,
#         0.5    , 0.53125, 0.40625, 0.53125, 0.6875 , 0.65625, 0.59375,
#         0.28125, 0.4375 , 0.375  , 0.59375, 0.46875, 0.4375 , 0.5    ,
# ...

# %%
def draw_pdf_contours(dist,save,  nlevels=200, subdiv=8, cm='magma', **kwargs):
    import math

    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    pvals = [dist.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]
    
    plt.tricontourf(trimesh, pvals, nlevels, **kwargs, cmap=cm)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.savefig(save)
    return pvals

# %%
draw_pdf_contours(Dirichlet(1), './dir1.eps')

# %%
draw_pdf_contours(Dirichlet(0.995), 'dir0995.png', cm='plasma')

# %%
draw_pdf_contours(Dirichlet(5.0), 'dir5.png', cm='plasma')

# %%
import scipy.special as st

# %%
from torch.distributions.relaxed_categorical import RelaxedOneHotCategorical
import torch as t

# %%
c = RelaxedOneHotCategorical(t.tensor([1.0]), t.tensor([1.0, 1.0, 1.0]))

# %%
np.exp(c.log_prob(t.tensor([0.2, 0.2, 0.3]))).numpy()[0]
# Out:
# 5.8593755

# %%
class GS:
    def __init__(self, x, s=t.tensor([1.0, 1.0, 1.0])):
        self.c = c = RelaxedOneHotCategorical(t.tensor([x]), s)
    def pdf(self, x):
        x = x *0.95+0.01
        
        return np.exp(self.c.log_prob(t.tensor(np.array(x).astype(np.float32)))).numpy()[0]

# %%
draw_pdf_contours(GS(0.0), 'gs0.eps')

# %%
draw_pdf_contours(GS(5.0), 'gs5.png', cm='plasma')

# %%
draw_pdf_contours(GS(5.0, t.tensor([0.1, 0.1, 10.0])), 'gs5_shift.png', cm='plasma')

# %%
draw_pdf_contours(GS(1.0), 'gs1.png', cm='plasma')

# %%
draw_pdf_contours(GS(1.0),  'test')

# %%
class GS2:
    def __init__(self, d,  x):
        self.c = c = RelaxedOneHotCategorical(t.tensor([x]), t.tensor(d))
    def pdf(self, x):
        x = x *0.95+0.01
        
        return np.exp(self.c.log_prob(t.tensor(np.array(x).astype(np.float32)))).numpy()[0]

# %%
draw_pdf_contours(GS2(np.array([1.0, 1.0, 1.0]).astype(np.float32),2.0),  'combinations_1', cm='plasma')

# %%
draw_pdf_contours(GS2(np.array([1.0, 0.1, 1.0]).astype(np.float32),2.0),  'combinations_2', cm='plasma')

# %%
draw_pdf_contours(GS2(np.array([1.0, 0.1, 0.1]).astype(np.float32),2.0),  'combinations_3', cm='plasma')

# %%
c = RelaxedOneHotCategorical(t.tensor([1.0]), t.tensor([1.0, 1.0, 1.0]))

# %%
c.log_probob(t.tensor([1.0, 0.0, 0.0]))
# Out:
# tensor([nan])

# %%
class GS3:
    def __init__(self, vectors, temp):
        self.c = []
        for v in vectors:
            self.c.append(RelaxedOneHotCategorical(t.tensor(temp),t.tensor(v)))
    def pdf(self, x):
        x = x *0.95+0.01
        s =0 
        for v in self.c:
            s-=v.log_prob(t.tensor(np.array(x).astype(np.float32)))
        return s
class GS4:
    def __init__(self, vectors, temp):
        self.c = []
        self.temp = temp
        for v in vectors:
            self.c.append(RelaxedOneHotCategorical(t.tensor(temp),t.tensor(v)))
    def pdf(self, x):
        x = x *0.95+0.01
        s =0
        gs = RelaxedOneHotCategorical(t.tensor(self.temp),t.tensor(x).float())
            
        for _ in range(1):
            for v in self.c:
                #print (gs.sample())
                sample = gs.sample()
                s+=gs.log_prob(sample)
                s-=v.log_prob(sample)
        return s

# %%
_= draw_pdf_contours(GS4([np.array([0.99, 0.005, 0.005]).astype(np.float32)],0.2),  'struct_reg_2', cm='plasma')

# %%
#import torch.tensor as t
te = 1.0
_= draw_pdf_contours(GS4([np.array([0.99, 0.005, 0.005]).astype(np.float32),np.array([0.005, 0.99, 0.005]).astype(np.float32)],te),  'struct_reg_3', cm='plasma')

# %%
draw_pdf_contours(GS3([],2.0),  'struct_reg_1', cm='plasma')

# %%
#import torch.tensor as t
te = 0.2
pvals = draw_pdf_contours(GS4([np.array([0.99, 0.005, 0.005]).astype(np.float32),np.array([0.005, 0.99, 0.005]).astype(np.float32),np.array([0.33, 0.33, 0.33]).astype(np.float32)],te),  'test', cm='plasma')

# %%
g = GS4([np.array([0.99, 0.005, 0.005]).astype(np.float32),np.array([0.005, 0.99, 0.005]).astype(np.float32), np.array([0.33, 0.33, 0.33]).astype(np.float32)],te)

# %%
g.pdf(np.array([0.0, 1.0, 0.0])), g.pdf(np.array([0.0, 0.0, 1.0])), g.pdf(np.array([1.0, 0.0, 0.0])), g.pdf(np.array([0.33, 0.33, 0.33]))
# Out:
# (tensor(-60.2227), tensor(-89.9796), tensor(-109.4520), tensor(-5.0397))

# %%
pvals
# Out:
# [tensor(-77.3271),
#  tensor(-87.0947),
#  tensor(-50.9383),
#  tensor(-31.3049),
#  tensor(-37.2650),
#  tensor(-6.6777),
#  tensor(-39.7873),
#  tensor(-35.5493),
#  tensor(-32.4428),
#  tensor(2.1987),
#  tensor(8.7249),
#  tensor(-11.6130),
#  tensor(-36.5187),
#  tensor(-20.4639),
#  tensor(-29.5743),
#  tensor(-53.6748),
#  tensor(-38.1069),
#  tensor(-18.7624),
#  tensor(-33.6677),
#  tensor(-55.1872),
#  tensor(-15.7442),
#  tensor(2.4391),
#  tensor(-51.8323),
#  tensor(-17.3256),
#  tensor(1.4051),
#  tensor(4.1482),
#  tensor(-22.9806),
#  tensor(15.6969),
#  tensor(-51.2955),
#  tensor(-2.1600),
#  tensor(6.2718),
#  tensor(-14.3151),
#  tensor(-4.6135),
#  tensor(-20.3162),
#  tensor(-14.9356),
#  tensor(-16.9803),
#  tensor(-22.2986),
#  tensor(-16.7882),
#  tensor(-26.7393),
#  tensor(-26.7944),
#  tensor(-3.7150),
#  tensor(-19.2142),
#  tensor(-8.0507),
#  tensor(-34.9167),
#  tensor(8.0646),
#  tensor(-22.5927),
#  tensor(-29.4920),
#  tensor(-36.8349),
# ...

# %%
v = np.array([0.01, 0.98, 0.01])
g.c[0].log_prob(t.tensor(v).float()), g.c[1].log_prob(t.tensor(v).float()),  g.c[2].log_prob(t.tensor(v).float())
# Out:
# (tensor(-4.8098), tensor(-2.1126), tensor(3.1618))

# %%
v = np.array([0.01, 0.01, 0.98])
g.c[0].log_prob(t.tensor(v).float()), g.c[1].log_prob(t.tensor(v).float()),  g.c[2].log_prob(t.tensor(v).float())
# Out:
# (tensor(-4.8098), tensor(-4.8098), tensor(3.1618))

# %%
v = np.array([0.33, 0.33, 0.33])
g.c[0].log_prob(t.tensor(v).float()), g.c[1].log_prob(t.tensor(v).float()),  g.c[2].log_prob(t.tensor(v).float())
# Out:
# (tensor(-9.8064), tensor(-9.8064), tensor(-2.4956))
